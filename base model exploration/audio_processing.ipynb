# %%
# %load_ext autoreload
# %autoreload 2
import audio_preprocessing 


path='./data/LibriSpeech/test-clean/260/123286/260-123286-0000.flac'

audio_preprocessing.read_audio(path, remove_noise= False)
# Out:
# C:\Users\nguye\Documents\GitHub\Capstone-Audio-Transcription\base model exploration\audio_preprocessing.py:47: FutureWarning: Pass y=[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -9.15527344e-05
#  -9.15527344e-05 -9.15527344e-05], S=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   print('avg RMS', np.mean(librosa.feature.rms(audio,sampling_rate)))
# avg RMS 0.03899768169971615
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# array([ 0.        ,  0.        ,  0.        , ..., -0.00019558,
#        -0.00019558, -0.00019558])

# %%
path='./data/LibriSpeech/test-clean/260/123286/260-123286-0000.flac'

audio_preprocessing.read_audio(path, remove_noise= True)
# Out:
# C:\Users\nguye\Documents\GitHub\Capstone-Audio-Transcription\base model exploration\audio_preprocessing.py:43: FutureWarning: Pass y=[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -9.15527344e-05
#  -9.15527344e-05 -9.15527344e-05], S=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   display(Audio_display(audio, rate=sampling_rate, autoplay=False))
# avg RMS 0.03899768169971615
# removing noise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -8.27466702e-07, -1.11932136e-05, -6.75760750e-06])

# %%
path='./data/noisy_audio.wav'

audio_preprocessing.read_audio(path, remove_noise= True)
# Out:
# C:\Users\nguye\Documents\GitHub\Capstone-Audio-Transcription\base model exploration\audio_preprocessing.py:64: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   if len(audio.shape) > 1:
# C:\Users\nguye\Documents\GitHub\Capstone-Audio-Transcription\base model exploration\audio_preprocessing.py:43: FutureWarning: Pass y=[ 0.00740571  0.00714186 -0.00712445 ...  0.00115432 -0.00870774
#   0.        ], S=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   display(Audio_display(audio, rate=sampling_rate, autoplay=False))
# avg RMS 0.08432311153809552
# removing noise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ...

# %%
path='./data/noisy_audio_2.wav'

audio_preprocessing.read_audio(path, remove_noise= True)
# Out:
# C:\Users\nguye\Documents\GitHub\Capstone-Audio-Transcription\base model exploration\audio_preprocessing.py:64: FutureWarning: Pass orig_sr=44100, target_sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   if len(audio.shape) > 1:
# C:\Users\nguye\Documents\GitHub\Capstone-Audio-Transcription\base model exploration\audio_preprocessing.py:43: FutureWarning: Pass y=[0.05495834 0.04837152 0.03759457 ... 0.21736002 0.25639508 0.        ], S=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   display(Audio_display(audio, rate=sampling_rate, autoplay=False))
# avg RMS 0.1573980998833446
# removing noise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ...
