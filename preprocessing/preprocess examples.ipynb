# %%
import librosa
import numpy as np
import colorednoise as cn
from audio_preprocess import add_noise, down_sample, add_signals

from IPython.display import Audio

# %%
#for testing
'''
file_path = r'path\to\file'
signal, sr = librosa.load(file_path, sr = 16000)

add_noise(signal,sample_rate=16000)
'''

filename = librosa.ex('brahms')
y, sr = librosa.load(filename, offset=15.0, duration=5.0)

path = librosa.ex('trumpet')
signal, sr = librosa.load(path, sr = 16000)

test = add_noise(signal, noise_percentage_factor = .01, sample_rate=16000, noise_type='white')

test2 = down_sample(signal, output_sr = 1000)

test3 = add_signals(signal, y)

Audio(test, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
